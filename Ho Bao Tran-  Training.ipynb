# %%
import os
import warnings
import cv2
import keras
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import pandas as pd
from PIL import Image
from keras import models, layers, optimizers
from keras.applications.vgg16 import VGG16
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Dense, Dropout, Flatten
from keras.models import Model
from keras.preprocessing import image as image_utils
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Dinh nghia cac bien

gestures = {'L_': 'L',
           'fi': 'E',
           'ok': 'F',
           'pe': 'V',
           'pa': 'B'
            }

gestures_map = {'E': 0,
                'L': 1,
                'F': 2,
                'V': 3,
                'B': 4
                }


gesture_names = {0: 'E',
                 1: 'L',
                 2: 'F',
                 3: 'V',
                 4: 'B'}
#Setting google drive as a directory for dataset
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
image_path = '/content/gdrive/MyDrive/dataHandLang'
models_path = '/content/gdrive/MyDrive/handpose.hdf5'
rgb = False
imageSize = 224

# %%
# Ham xu ly anh resize ve 224x224 va chuyen ve numpy array
def process_image(path):
    img = Image.open(path)
    img = img.resize((imageSize, imageSize))
    img = np.array(img)
    return img

# Xu ly du lieu dau vao
def process_data(X_data, y_data):
    X_data = np.array(X_data, dtype = 'float32')
    if rgb:
        pass
    else:
        X_data = np.stack((X_data,)*3, axis=-1)
    X_data /= 255
    y_data = np.array(y_data)
    y_data = to_categorical(y_data)
    return X_data, y_data

# %%
def walk_file_tree(image_path):
    X_data = []
    y_data = []
    for directory, subdirectories, files in os.walk(image_path):
        for file in files:
            if not file.startswith('.'):
                path = os.path.join(directory, file)
                gesture_name = gestures[file[0:2]]
                print(gesture_name)
                print(gestures_map[gesture_name])
                y_data.append(gestures_map[gesture_name])
                X_data.append(process_image(path))

            else:
                continue

    X_data, y_data = process_data(X_data, y_data)
    return X_data, y_data

# %%
# Load du lieu vao X va Y
X_data, y_data = walk_file_tree(image_path)

# Phan chia du lieu train va test theo ty le 80/20
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size = 0.2, random_state=12, stratify=y_data)

# Dat cac checkpoint de luu lai model tot nhat
model_checkpoint = ModelCheckpoint(filepath=models_path, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_acc',
                               min_delta=0,
                               patience=10,
                               verbose=1,
                               mode='auto',
                               restore_best_weights=True)
# Out:
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0
# E
# 0

# %%
import tensorflow as tf 
# Khoi tao model
model1 = VGG16(weights='imagenet', include_top=False, input_shape=(imageSize, imageSize, 3))
optimizer1 = tf.keras.optimizers.Adam()
base_model = model1

# Them cac lop ben tren
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu', name='fc1')(x)
x = Dense(128, activation='relu', name='fc2')(x)
x = Dense(128, activation='relu', name='fc2a')(x)
x = Dense(128, activation='relu', name='fc3')(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu', name='fc4')(x)

predictions = Dense(5, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)
# Dong bang cac lop duoi, chi train lop ben tren minh them vao
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stopping, model_checkpoint])

# Luu model da train ra file
model.save('/content/gdrive/MyDrive/handpose.h5')
# Out:
# Epoch 1/50
# 6/6 [==============================] - ETA: 0s - loss: 0.4141 - accuracy: 0.8409 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 227s 39s/step - loss: 0.4141 - accuracy: 0.8409 - val_loss: 1.4901e-08 - val_accuracy: 1.0000
# Epoch 2/50
# 6/6 [==============================] - ETA: 0s - loss: 8.6690e-06 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 230s 39s/step - loss: 8.6690e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/50
# 6/6 [==============================] - ETA: 0s - loss: 1.0160e-09 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 1.0160e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 227s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 6/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 7/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 8/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 226s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 9/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 226s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 10/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 262s 46s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 12/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 13/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 14/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 15/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 16/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 17/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 18/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 19/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 20/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 22/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 226s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 23/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 24/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 25/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 226s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 26/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 27/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 28/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 29/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 226s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 30/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 31/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 32/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 33/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 34/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 226s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 35/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 36/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 37/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 38/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 40/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 41/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 42/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 43/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 224s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 44/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 222s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 45/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 46/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 47/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 48/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 39s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 225s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000 WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 223s 38s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
